# %%
from PyPDF2 import PdfFileReader
import re
from datetime import datetime
input1 = PdfFileReader(open("/home/sam/Workspace/CPCC/pdfimport/pdf-table-extract/example/Tides2017-ChisMall.pdf", "rb"))

re_date = re.compile(r'(\w+ \d+ \w+)+')
re_time = re.compile(r'(\d+:\d+)+')
re_mesurements = re.compile(r'(\d+\.\d)+')
final_data = {}

for page in input1.pages:
	page_data = page.extractText()
	date = None
	tides_times = []
	tides_levels = []
	for item in page_data.split('\n'):
		if re_date.match(item):
			if date != None:
				final_data[date] = []
				for index in range(len(tides_times)):
					final_data[date].append([tides_levels[index], tides_times[index]])
			date = datetime.strptime(item.replace(' ','')+'2017','%a%d%b%Y' )
		if re_time.match(item):
			tides_times.append(datetime.strptime(item,'%H:%M').time())
		if re_mesurements.match(item):
			tides_levels.append(float(item))
# Out:
# {datetime.datetime(2017, 3, 13, 0, 0): [[0.91, datetime.time(1, 13)], [6.52, datetime.time(6, 8)], [0.84, datetime.time(13, 34)], [6.39, datetime.time(18, 41)], [1.07, datetime.time(1, 32)], [6.24, datetime.time(6, 40)], [1.05, datetime.time(13, 49)], [6.12, datetime.time(19, 15)], [1.29, datetime.time(1, 53)], [5.93, datetime.time(7, 14)], [1.32, datetime.time(14, 18)], [5.86, datetime.time(20, 2)], [1.55, datetime.time(2, 30)], [5.64, datetime.time(8, 44)], [1.62, datetime.time(15, 2)], [5.64, datetime.time(21, 8)], [1.81, datetime.time(3, 24)], [5.53, datetime.time(9, 58)], [1.8, datetime.time(16, 13)], [5.61, datetime.time(22, 16)], [1.81, datetime.time(4, 51)], [5.71, datetime.time(11, 7)], [1.58, datetime.time(17, 34)], [5.84, datetime.time(23, 29)], [1.42, datetime.time(6, 1)], [6.08, datetime.time(12, 18)], [1.26, datetime.time(19, 13)], [6.23, datetime.time(0, 40)], [1.08, datetime.time(7, 56)], [6.45, datetime.time(13, 15)], [1.03, datetime.time(20, 13)], [6.55, datetime.time(1, 32)], [0.87, datetime.time(8, 50)], [6.73, datetime.time(13, 59)], [0.91, datetime.time(21, 4)], [6.75, datetime.time(2, 14)], [0.75, datetime.time(10, 7)], [6.92, datetime.time(14, 39)], [0.83, datetime.time(21, 52)], [6.88, datetime.time(2, 53)], [0.64, datetime.time(11, 1)], [7.09, datetime.time(15, 18)], [0.72, datetime.time(22, 41)], [6.99, datetime.time(3, 30)], [0.5, datetime.time(11, 46)], [7.21, datetime.time(15, 58)], [0.6, datetime.time(23, 30)], [7.08, datetime.time(4, 8)], [0.4, datetime.time(12, 26)], [7.24, datetime.time(16, 38)], [0.53, datetime.time(0, 14)], [7.11, datetime.time(4, 46)], [0.41, datetime.time(12, 59)], [7.14, datetime.time(17, 18)], [0.57, datetime.time(0, 52)], [7.05, datetime.time(5, 23)], [0.53, datetime.time(13, 23)], [6.94, datetime.time(17, 58)], [0.69, datetime.time(1, 26)], [6.92, datetime.time(6, 3)], [0.69, datetime.time(13, 46)], [6.68, datetime.time(18, 39)], [0.85, datetime.time(1, 59)], [6.71, datetime.time(6, 47)], [0.89, datetime.time(14, 8)], [6.4, datetime.time(19, 25)], [1.06, datetime.time(2, 32)], [6.43, datetime.time(7, 41)], [1.15, datetime.time(14, 38)], [6.13, datetime.time(20, 23)], [1.29, datetime.time(3, 9)], [6.18, datetime.time(8, 58)], [1.39, datetime.time(15, 39)], [5.96, datetime.time(21, 46)], [1.38, datetime.time(4, 24)], [6.15, datetime.time(10, 46)], [1.4, datetime.time(17, 28)], [6.06, datetime.time(23, 24)], [1.2, datetime.time(6, 28)], [6.38, datetime.time(12, 4)], [1.17, datetime.time(19, 9)], [6.41, datetime.time(0, 33)], [0.85, datetime.time(8, 2)], [6.74, datetime.time(13, 6)], [0.87, datetime.time(20, 20)], [6.73, datetime.time(1, 27)], [0.52, datetime.time(9, 32)], [7.01, datetime.time(13, 56)], [0.69, datetime.time(21, 24)], [6.91, datetime.time(2, 12)], [0.38, datetime.time(10, 22)], [7.12, datetime.time(14, 40)], [0.64, datetime.time(22, 6)], [7.01, datetime.time(2, 52)], [0.36, datetime.time(11, 4)], [7.17, datetime.time(15, 19)], [0.64, datetime.time(22, 29)]], datetime.datetime(2017, 5, 3, 0, 0): [[7.01, datetime.time(4, 1)], [0.51, datetime.time(11, 11)], [7.09, datetime.time(16, 28)], [0.62, datetime.time(23, 39)], [7.09, datetime.time(4, 33)], [0.5, datetime.time(11, 51)], [7.08, datetime.time(16, 57)], [0.61, datetime.time(0, 18)], [7.07, datetime.time(5, 4)], [0.52, datetime.time(12, 30)], [6.99, datetime.time(17, 24)], [0.64, datetime.time(0, 54)], [6.91, datetime.time(5, 37)], [0.59, datetime.time(13, 4)], [6.81, datetime.time(17, 53)], [0.73, datetime.time(1, 25)], [6.67, datetime.time(6, 10)], [0.74, datetime.time(13, 30)], [6.58, datetime.time(18, 22)], [0.87, datetime.time(1, 50)], [6.41, datetime.time(6, 44)], [0.92, datetime.time(13, 51)], [6.34, datetime.time(18, 55)], [1.0, datetime.time(2, 1)], [6.17, datetime.time(7, 22)], [1.12, datetime.time(14, 11)], [6.1, datetime.time(19, 32)], [1.12, datetime.time(1, 50)], [5.93, datetime.time(8, 7)], [1.36, datetime.time(14, 46)], [5.84, datetime.time(20, 22)], [1.32, datetime.time(2, 58)], [5.73, date ...

# %%
from PyPDF2 import PdfFileReader
import re
from datetime import datetime
import numpy as np
import numpy.polynomial.polynomial as poly
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d, Rbf, InterpolatedUnivariateSpline
input1 = PdfFileReader(open("/home/sam/Workspace/CPCC/pdfimport/pdf-table-extract/example/Tides2017-ChisMall.pdf", "rb"))

re_date = re.compile(r'(\w+ \d+ \w+)+')
re_time = re.compile(r'(\d+:\d+)+')
re_mesurements = re.compile(r'(\d+\.\d)+')
tides_times = []
tides_levels = []

for page in input1.pages:
    page_data = page.extractText()
    date = None
    for item in page_data.split('\n'):
        if re_date.match(item):
            date = datetime.strptime(item.replace(' ','')+'2017','%a%d%b%Y' )
        if re_time.match(item):
            time = datetime.strptime(item,'%H:%M').time()
            date_item = datetime.combine(date, time)
            tides_times.append(date_item.timestamp())
        if re_mesurements.match(item):
            tides_levels.append(float(item))

x = tides_times[20:35]
y = tides_levels[20:35]
s = interp1d(x,y,kind='quadratic',assume_sorted=True)
#xnew = s(x)
xnew = np.linspace(x[0],x[-1])
ynew = s(xnew)

ius = Rbf(x, y)
yi = ius(xnew)

#coefs = poly.polyfit(x, y, 3)
#ffit = poly.Polynomial(coefs)

plt.plot(x,y,'o',xnew, ynew,'b',xnew,yi)
plt.show()

# %%
from datetime import datetime
now = datetime.now()
print(now.timestamp())
# Out:
# 1490820466.625445
